# %%
using Plots
include("ReadAsd.jl")
# Out:
# readAsd (generic function with 1 method)

# %%
asd = readAsd("../8011.asd")
print(asd.header)
# Out:
# HeaderV0(0, "topography", "none", 129, 32, 12, 88, 300, 80, 40, 150, 75, 147.0799102783203, 3.200000047683716, 4.0, 10.0, 4096.0, false, 1, 2009-01-17T03:50:44, 5, 850.0, 2280.0, 0, 0, 0, 2000, 2000, 5, 8011, [0, 75, 0, 111, 0, 100, 0, 101, 0, 114, 0, 97], 5.0, 45.900001525878906, 5, [0, 68, 0, 80, 0, 80, 0, 67, 0, 32, 0, 58, 0, 32, 0, 68, 0, 80, 0, 84, 0, 65, 0, 80, 0, 32, 0, 58, 0, 32, 0, 98, 0, 105, 0, 111, 0, 116, 0, 105, 0, 110, 0, 45, 0, 99, 0, 97, 0, 112, 0, 68, 0, 80, 0, 80, 0, 69, 0, 32, 0, 61, 0, 32, 0, 56, 0, 55, 0, 46, 0, 53, 0, 32, 0, 58, 0, 32, 0, 50, 0, 46, 0, 53, 0, 32, 0, 58, 0, 32, 0, 49, 0, 48, 0, 13, 0, 10, 0, 43, 0, 83, 0, 65, 0, 43, 0, 98, 0, 105, 0, 111, 0, 116, 0, 105, 0, 110, 0, 65, 0, 99, 0, 116, 0, 105, 0, 110, 0, 43, 0, 77, 0, 121, 0, 111, 0, 86, 0, 45, 0, 72, 0, 77, 0, 77, 0, 13, 0, 10, 0, 49, 0, 117, 0, 77, 0, 32, 0, 65, 0, 84, 0, 80, 0, 13, 0, 10, 0, 53, 0, 109, 0, 77, 0, 32, 0, 68, 0, 84, 0, 84, 0, 13, 0, 10, 0, 50, 0, 53, 0, 109, 0, 77, 0, 32, 0, 75, 
# ...

# %%
plt = []
for i in 1:6
    push!(plt, heatmap(asd.frames[i].data'))
end
println(size(asd.frames))
plot(plt...)
# Out:
# (2000,)
